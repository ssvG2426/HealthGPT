# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Cell 1/11 - Install & imports
# !pip install -q datasets sentence-transformers faiss-cpu transformers nltk accelerate keybert[gensim] sentencepiece scikit-learn rank-bm25 evaluate bert-score rouge-score sacremoses

import os, sys, time, json, pickle, warnings, re
warnings.filterwarnings("ignore")

import numpy as np
import torch
from datasets import load_dataset
from sklearn.model_selection import train_test_split

import nltk
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

from sentence_transformers import SentenceTransformer, CrossEncoder, util
from transformers import AutoTokenizer, AutoModelForCausalLM
from keybert import KeyBERT
import faiss
from rank_bm25 import BM25Okapi

# Evaluation libs
from evaluate import load as eval_load

# quick eval metrics
bleu_metric = eval_load("bleu")
rouge_metric = eval_load("rouge")
bertscore_metric = eval_load("bertscore")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def log(msg): print(f"[{time.strftime('%H:%M:%S')}] {msg}")
log(f"Device: {device} | CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    try:
        print("GPU:", torch.cuda.get_device_name(0))
    except Exception:
        pass
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 50.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 45.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.5 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 21.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 42.6 kB/s eta 0:00:0000:01
#   Building wheel for rouge-score (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# 2025-09-20 16:54:42.040204: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758387282.233695      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758387282.298115      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# [16:54:58] Device: cuda | CUDA available: True
# GPU: Tesla T4

# %%
# Cell 2/11 - Load dataset and convert to QA pairs
log("Loading dataset and converting to QA pairs...")

# CHANGE THIS if you want a different dataset:7
DATASET_NAME = "altaidevorg/women-health-mini"
SPLIT = "train"

ds = load_dataset(DATASET_NAME, split=SPLIT)

qa_data = []
for row in ds:
    # many datasets store dialogues under different keys; handle robustly
    conv = None
    if isinstance(row, dict):
        for k in ["conversations", "conversation", "dialog", "dialogue", "messages"]:
            if k in row:
                conv = row[k]
                break
    if not conv:
        # skip rows that don't contain dialogue-like content
        continue

    # conv is often a list of dicts or list of strings
    user_msgs = []
    assistant_msgs = []

    if isinstance(conv, list) and len(conv) > 0:
        if isinstance(conv[0], dict):
            # common shapes:
            #  - {"from": "human", "value": "..."}
            #  - {"role": "user", "content": "..."}
            if "from" in conv[0] and "value" in conv[0]:
                user_msgs = [m["value"] for m in conv if m.get("from") in ("human", "user")]
                assistant_msgs = [m["value"] for m in conv if m.get("from") in ("assistant", "bot", "system")]
            elif "role" in conv[0] and "content" in conv[0]:
                user_msgs = [m["content"] for m in conv if m.get("role") in ("user", "human")]
                assistant_msgs = [m["content"] for m in conv if m.get("role") in ("assistant", "bot")]
            else:
                # fallback: find any textual fields
                texts = []
                for m in conv:
                    if isinstance(m, dict):
                        # pick first textual field
                        for field in ["value", "content", "text", "utterance"]:
                            if field in m and isinstance(m[field], str):
                                texts.append(m[field])
                                break
                    elif isinstance(m, str):
                        texts.append(m)
                if len(texts) >= 2:
                    user_msgs = [texts[0]]
                    assistant_msgs = texts[1:]
        else:
            # conv is a list of strings
            if len(conv) >= 2:
                user_msgs = [conv[0]]
                assistant_msgs = conv[1:]

    if user_msgs and assistant_msgs:
        question = " ".join(user_msgs).strip()
        answer = " ".join(assistant_msgs).strip()
        if question and answer:
            qa_data.append({"question": question, "answer": answer})

if len(qa_data) == 0:
    raise ValueError("No QA pairs extracted from dataset. Inspect dataset structure or change DATASET_NAME.")

train_data, test_data = train_test_split(qa_data, test_size=0.2, random_state=42)
log(f"Prepared QA dataset: {len(train_data)} train, {len(test_data)} test")
print("Sample QA pair (train):", train_data[0])
# Out:
# [16:54:58] Loading dataset and converting to QA pairs...
# README.md: 0.00B [00:00, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# women-health-mini.jsonl:   0%|          | 0.00/35.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10348 [00:00<?, ? examples/s]
# [16:55:01] Prepared QA dataset: 8278 train, 2070 test
# Sample QA pair (train): {'question': 'What are some natural ways to manage PMS symptoms?', 'answer': "Many women experience premenstrual syndrome (PMS), a collection of physical and emotional symptoms that occur in the days leading up to menstruation. While the severity varies greatly,  managing PMS naturally is possible for many, focusing on lifestyle changes and dietary adjustments.  Here's what I recommend, emphasizing evidence-based approaches:\n\n\n**Dietary Changes:**\n\n* **Reduce Refined Carbohydrates and Sugar:**  These can worsen mood swings and bloating.  Opt for complex carbohydrates like whole grains, fruits, and vegetables for sustained energy release and better blood sugar control.\n* **Increase Magnesium Intake:** Magnesium plays a crucial role in regulating mood and reducing muscle cramps.  Good sources include dark leafy greens, nuts, seeds, and legumes. Consider a magnesium supplement, but always consult with me first to determine the appropriate dosage, as excessive magnesium can have side effects.\n* **Calcium and Vitamin D:**  These are vital for bone health and can also help alleviate cramps.  Dairy products, leafy greens, and fortified foods are good sources.  Sun exposure also aids vitamin D synthesis.\n* **Increase Potassium Intake:**  Potassium helps balance sodium levels and can reduce bloating. Bananas, sweet potatoes, and spinach are excellent sources.\n* **Limit Sodium:**  Excessive sodium contributes to water retention and bloating.  Reduce processed foods, salty snacks, and restaurant meals.\n* **Omega-3 Fatty Acids:** Found in fatty fish like salmon, flaxseeds, and chia seeds, these have anti-inflammatory properties and may help alleviate PMS symptoms.\n* **Fiber:**  A high-fiber diet promotes regular bowel movements and can alleviate constipation, a common PMS symptom.\n\n\n**Lifestyle Modifications:**\n\n* **Regular Exercise:**  Physical activity is a powerful mood booster and can help alleviate stress, cramping, and bloating. Aim for at least 30 minutes of moderate-intensity exercise most days of the week.  Gentle yoga or Pilates can be particularly beneficial.\n* **Stress Management:**  Stress significantly exacerbates PMS symptoms.  Incorporate stress-reducing techniques such as meditation, deep breathing exercises, yoga, spending time in nature, or engaging in hobbies you enjoy.\n* **Adequate Sleep:**  Aim for 7-8 hours of quality sleep per night.  Establish a regular sleep schedule and create a relaxing bedtime routine.\n* **Hydration:** Drink plenty of water throughout the day to prevent dehydration, which can worsen bloating and headaches.\n\n\n**Herbal Remedies (Use with Caution):**\n\n* **Chasteberry (Vitex agnus-castus):**  Some studies suggest chasteberry may help regulate hormones and reduce PMS symptoms, but more research is needed.  **Crucially**,  it can interact with certain medications, so it's essential to discuss its use with me before trying it.\n* **Evening Primrose Oil:** Contains gamma-linolenic acid (GLA), which some believe may help reduce breast tenderness and other PMS symptoms.  Again, discuss its use with me first, especially if you're on blood thinners.\n\n\n**Important Note:** While these natural approaches are often helpful, they don't work for everyone.  If your PMS symptoms are severe, significantly impacting your quality of life, or if you suspect another underlying condition, please schedule an appointment with me so I can perform a thorough evaluation.  We can discuss further management options, including prescription medications if necessary.  It is crucial to approach PMS holistically, considering both the individual and the interplay of various factors."}

# %%
# Cell 3/11 - Chunking helpers
def create_sentence_chunks(data, window_size=3, stride=1, min_chars=40):
    chunks = []
    for idx, item in enumerate(data):
        text = item.get("answer", "") or item.get("text", "")
        if not isinstance(text, str):
            continue
        sentences = sent_tokenize(text)
        if not sentences:
            if len(text) > min_chars:
                chunks.append({"chunk": text, "source_idx": idx})
            continue
        if len(sentences) <= window_size:
            chunks.append({"chunk": " ".join(sentences), "source_idx": idx})
            continue
        for i in range(0, max(1, len(sentences) - window_size + 1), stride):
            chunk = " ".join(sentences[i:i+window_size])
            chunks.append({"chunk": chunk, "source_idx": idx})
    return chunks

from transformers import AutoTokenizer
# token-chunking helper (optional)
def create_token_chunks(data, tokenizer, chunk_tokens=400, overlap=100, field="answer"):
    chunks = []
    for idx, item in enumerate(data):
        text = item.get(field, "") or item.get("text", "")
        if not isinstance(text, str) or len(text.strip())==0:
            continue
        tokens = tokenizer.encode(text, add_special_tokens=False)
        if not tokens:
            continue
        start = 0
        while start < len(tokens):
            end = min(start + chunk_tokens, len(tokens))
            piece = tokenizer.decode(tokens[start:end], skip_special_tokens=True)
            if piece and piece.strip():
                chunks.append({"chunk": piece, "source_idx": idx})
            if end == len(tokens):
                break
            start = max(0, end - overlap)
    return chunks

log("Chunking helpers ready.")
# Out:
# [16:55:01] Chunking helpers ready.

# %%
# Cell 4/11 - Load models (embedding + reranker + HyDE + generator)
log("Loading models (this can take time)...")

# Recommended biomedical sentence-transformer (semantic similarity = better completeness)
EMBED_MODEL = "pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb"  # domain-specific SBERT-style model
# Fallback to fast model if the above fails
FALLBACK_EMBED = "sentence-transformers/all-MiniLM-L6-v2"

try:
    embedder = SentenceTransformer(EMBED_MODEL, device=device)
    log(f"Loaded biomedical embedder: {EMBED_MODEL}")
except Exception as e:
    log(f"Could not load {EMBED_MODEL}: {e}. Falling back to {FALLBACK_EMBED}")
    embedder = SentenceTransformer(FALLBACK_EMBED, device=device)

# Cross-encoder reranker
CE_MODEL = "cross-encoder/ms-marco-MiniLM-L6-v2"
reranker = CrossEncoder(CE_MODEL, device=device)
log(f"Cross-encoder loaded: {CE_MODEL}")

# HyDE model (use BioGPT-Large for domain-grounded HyDE)
HYDE_MODEL = "microsoft/BioGPT-Large"
try:
    hyde_tokenizer = AutoTokenizer.from_pretrained(HYDE_MODEL)
    if hyde_tokenizer.pad_token is None:
        hyde_tokenizer.pad_token = hyde_tokenizer.eos_token
    hyde_model = AutoModelForCausalLM.from_pretrained(HYDE_MODEL).to(device)
    log(f"HyDE model loaded: {HYDE_MODEL}")
except Exception as e:
    log(f"Failed to load HyDE {HYDE_MODEL}: {e}. Falling back to gpt2")
    HYDE_MODEL = "gpt2"
    hyde_tokenizer = AutoTokenizer.from_pretrained(HYDE_MODEL)
    if hyde_tokenizer.pad_token is None:
        hyde_tokenizer.pad_token = hyde_tokenizer.eos_token
    hyde_model = AutoModelForCausalLM.from_pretrained(HYDE_MODEL).to(device)
    log("HyDE fallback gpt2 loaded.")

# Generation model: prefer Mistral-7B-Instruct (heavy). Provide fallback to BioGPT-Large for smaller GPU.
GEN_MODEL_PREFERRED = "microsoft/BioGPT-Large"

try:
    gen_tokenizer = AutoTokenizer.from_pretrained(GEN_MODEL_PREFERRED)
    if gen_tokenizer.pad_token is None:
        gen_tokenizer.pad_token = gen_tokenizer.eos_token
    gen_model = AutoModelForCausalLM.from_pretrained(GEN_MODEL_PREFERRED).to(device)
    log(f"Generator loaded: {GEN_MODEL_PREFERRED}")
except Exception as e:
    log(f"Could not load {GEN_MODEL_PREFERRED}: {e}. Falling back to {GEN_MODEL_FALLBACK}")
    GEN_MODEL_PREFERRED = GEN_MODEL_FALLBACK
    gen_tokenizer = AutoTokenizer.from_pretrained(GEN_MODEL_PREFERRED)
    if gen_tokenizer.pad_token is None:
        gen_tokenizer.pad_token = gen_tokenizer.eos_token
    gen_model = AutoModelForCausalLM.from_pretrained(GEN_MODEL_PREFERRED).to(device)
    log(f"Generator fallback loaded: {GEN_MODEL_PREFERRED}")

# KeyBERT for keyword extraction (lightweight)
kw_model = KeyBERT(model=embedder)
STOPWORDS = set(stopwords.words('english'))

log("All models loaded (or fell back).")
# Out:
# [16:55:01] Loading models (this can take time)...
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/412 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [16:55:09] Loaded biomedical embedder: pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# [16:55:11] Cross-encoder loaded: cross-encoder/ms-marco-MiniLM-L6-v2
# tokenizer_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/658 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/6.29G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.28G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# [16:57:04] HyDE model loaded: microsoft/BioGPT-Large
# [16:57:13] Generator loaded: microsoft/BioGPT-Large
# [16:57:13] All models loaded (or fell back).

# %%
# Cell 5/11 - Build chunks, compute embeddings, build FAISS + BM25; save index & id2doc
log("Creating sentence chunks from training data...")
sentence_chunks = create_sentence_chunks(train_data, window_size=3, stride=1)
id2doc = [c["chunk"] for c in sentence_chunks]
log(f"Created {len(id2doc)} chunks")

# Compute embeddings (may take time)
log("Computing embeddings for all chunks...")
chunk_embeddings = embedder.encode(id2doc, normalize_embeddings=True, convert_to_numpy=True, show_progress_bar=True, batch_size=64).astype("float32")

# FAISS index
dim = chunk_embeddings.shape[1]
index = faiss.IndexFlatIP(dim)
index.add(chunk_embeddings)
log(f"FAISS index built: {index.ntotal} vectors, dim={dim}")

# Save index and id2doc to disk (so you don't need to reindex)
faiss.write_index(index, "faiss.index")
with open("id2doc.pkl", "wb") as f:
    pickle.dump(id2doc, f)
log("Saved FAISS index (faiss.index) and id2doc.pkl")

# BM25
bm25_corpus = [word_tokenize(txt.lower()) for txt in id2doc]
bm25 = BM25Okapi(bm25_corpus)
log("BM25 built.")
# Out:
# [16:57:13] Creating sentence chunks from training data...
# [16:57:17] Created 222376 chunks
# [16:57:17] Computing embeddings for all chunks...
# Batches:   0%|          | 0/3475 [00:00<?, ?it/s]
# [17:17:28] FAISS index built: 222376 vectors, dim=768
# [17:17:28] Saved FAISS index (faiss.index) and id2doc.pkl
# [17:18:42] BM25 built.

# %%
# Cell 6/11 - Retrieval: HyDE + FAISS + BM25 + CrossEncoder rerank

def get_hyde_answer(query, max_length=100):
    prompt = f"Question: {query}\nAnswer:"
    inputs = hyde_tokenizer(prompt, return_tensors="pt", truncation=True, max_length=256).to(device)
    with torch.no_grad():
        outputs = hyde_model.generate(
            **inputs,
            max_length=inputs['input_ids'].shape[1] + max_length,
            do_sample=False,
            repetition_penalty=1.2,
            pad_token_id=hyde_tokenizer.eos_token_id
        )
    text = hyde_tokenizer.decode(outputs[0], skip_special_tokens=True)
    # Clean a bit
    return re.sub(r"\s+", " ", text.split("Answer:")[-1].strip())

def retrieve_with_hyde(query, k=30, hyde_weight=0.5, faiss_alpha=0.6):
    # HyDE pseudo-answer for improved embedding
    hyde_txt = get_hyde_answer(query)
    q_emb = embedder.encode([query], normalize_embeddings=True, convert_to_numpy=True).astype("float32")
    h_emb = embedder.encode([hyde_txt], normalize_embeddings=True, convert_to_numpy=True).astype("float32")
    merged_emb = (1 - hyde_weight) * q_emb + hyde_weight * h_emb

    D, I = index.search(merged_emb, k)
    faiss_candidates = list(dict.fromkeys(I[0].tolist()))

    tokenized_query = word_tokenize(query.lower())
    bm25_scores = bm25.get_scores(tokenized_query)
    bm25_top = np.argsort(bm25_scores)[::-1][:k].tolist()

    # Normalize FAISS scores & BM25
    faiss_norm = (D[0] - D[0].min()) / (D[0].ptp() + 1e-9)
    faiss_map = {idx: float(score) for idx, score in zip(I[0].tolist(), faiss_norm.tolist())}
    bm25_norm = (bm25_scores - bm25_scores.min()) / (bm25_scores.ptp() + 1e-9)

    merged = {}
    for idx in set(faiss_candidates + bm25_top):
        merged[idx] = faiss_alpha * faiss_map.get(idx, 0.0) + (1 - faiss_alpha) * float(bm25_norm[idx])
    merged_sorted = sorted(merged.items(), key=lambda x: x[1], reverse=True)[:k]
    candidate_indices = [idx for idx, _ in merged_sorted]
    return candidate_indices, hyde_txt

def rerank_chunks(query, candidate_indices, top_k=5, use_cross_encoder=True):
    texts = [id2doc[i] for i in candidate_indices]
    if use_cross_encoder and reranker:
        pairs = [(query, t) for t in texts]
        with torch.no_grad():
            scores = reranker.predict(pairs)
        order = np.argsort(scores)[::-1][:top_k]
        return [texts[i] for i in order]
    else:
        q_emb = embedder.encode([query], normalize_embeddings=True, convert_to_numpy=True)
        t_emb = embedder.encode(texts, normalize_embeddings=True, convert_to_numpy=True)
        sims = np.dot(t_emb, q_emb[0])
        order = np.argsort(sims)[::-1][:top_k]
        return [texts[i] for i in order]

# %%
# Cell 7/11 - Generation (Mistral or fallback) and extract_then_summarize

STRICT_FALLBACK = "Not enough information in the provided context."

def clean_output(text):
    # Remove meta tokens and artifacts and extra whitespace
    text = re.sub(r"(Answer:|Final answer:|<\s*/?\s\w+\s*>|</s>|▃)", "", text, flags=re.IGNORECASE)
    text = re.sub(r"\s+", " ", text).strip()
    # remove leading/trailing punctuation
    return text.strip(" \n\r\t\"'")

def generate_answer(query, contexts, max_new_tokens=220):
    # contexts: list of strings (chunks)
    if isinstance(contexts, list):
        context_block = "\n\n---\n".join(contexts)
    else:
        context_block = str(contexts)

    # Clean prompt: do NOT include meta instructions in final answer area
    prompt = f"Context:\n{context_block}\n\nQuestion: {query}\n\nAnswer:"
    inputs = gen_tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1024).to(device)
    with torch.no_grad():
        outputs = gen_model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            repetition_penalty=1.12,
            pad_token_id=gen_tokenizer.eos_token_id
        )
    text = gen_tokenizer.decode(outputs[0], skip_special_tokens=True)
    cleaned = clean_output(text.split("Answer:")[-1])
    return cleaned or STRICT_FALLBACK

def extract_then_summarize(query, contexts, top_sents=8, max_new_tokens=220):
    hyde_txt = get_hyde_answer(query)
    sents = []
    for ctx in contexts:
        sents.extend([s for s in sent_tokenize(ctx) if len(s.strip())>5])
    if not sents:
        return STRICT_FALLBACK

    qh_emb = embedder.encode([query, hyde_txt], normalize_embeddings=True, convert_to_tensor=True)
    s_emb = embedder.encode(sents, normalize_embeddings=True, convert_to_tensor=True)

    sim_q = util.cos_sim(s_emb, qh_emb[0]).cpu().numpy().reshape(-1)
    sim_h = util.cos_sim(s_emb, qh_emb[1]).cpu().numpy().reshape(-1)
    sims = 0.7 * sim_q + 0.3 * sim_h
    order = np.argsort(sims)[::-1][:top_sents]
    extract_block = "\n".join([sents[i] for i in order])

    prompt = f"Extracted sentences:\n{extract_block}\n\nQuestion: {query}\n\nAnswer:"
    inputs = gen_tokenizer(prompt, return_tensors="pt", truncation=True, max_length=1024).to(device)
    with torch.no_grad():
        outputs = gen_model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            repetition_penalty=1.12,
            pad_token_id=gen_tokenizer.eos_token_id
        )
    text = gen_tokenizer.decode(outputs[0], skip_special_tokens=True)
    cleaned = clean_output(text.split("Answer:")[-1])
    return cleaned or STRICT_FALLBACK

# %%
# Cell 8/11 - Evaluation metrics

def extract_keywords(text, top_n=8):
    if not text or len(text.split())<3:
        return []
    kws = kw_model.extract_keywords(text, keyphrase_ngram_range=(1,2), stop_words='english', top_n=top_n)
    return [kw for kw, _ in kws]

def retrieval_relevance_score(query, top_k=10):
    q_emb = embedder.encode([query], normalize_embeddings=True, convert_to_numpy=True).astype("float32")
    D, I = index.search(q_emb, top_k)
    scores = np.clip(D[0], -1.0, 1.0)
    return float(((scores + 1.0) / 2.0).mean())

def answer_completeness_score(answer, retrieved_chunks, sim_threshold=0.62):
    # Semantic completeness: how many unique key-facts from retrieved chunks are semantically present in answer
    all_facts = []
    for chunk in retrieved_chunks:
        all_facts.extend(extract_keywords(chunk, top_n=4))
    unique_facts = list(dict.fromkeys([f.lower().strip() for f in all_facts if f]))
    if not unique_facts:
        return 0.0

    # embed each fact and the answer as sentences
    try:
        answer_emb = embedder.encode([answer], normalize_embeddings=True, convert_to_tensor=True)
        fact_embs = embedder.encode(unique_facts, normalize_embeddings=True, convert_to_tensor=True)
        sims = util.cos_sim(answer_emb, fact_embs).cpu().numpy()[0]
        covered = (sims >= sim_threshold).sum()
        return float(covered / max(1, len(unique_facts)))
    except Exception as e:
        log(f"Error in completeness scoring: {e}")
        return 0.0

def faithfulness_score(answer, context_chunks, sentence_threshold=0.5):
    if not answer or not context_chunks:
        return 0.0
    ans_sents = sent_tokenize(answer)
    ctx_sents = []
    for c in context_chunks:
        ctx_sents += sent_tokenize(c)
    if not ans_sents or not ctx_sents:
        return 0.0
    try:
        ans_emb = embedder.encode(ans_sents, normalize_embeddings=True, convert_to_tensor=True)
        ctx_emb = embedder.encode(ctx_sents, normalize_embeddings=True, convert_to_tensor=True)
        sim_mtx = util.cos_sim(ans_emb, ctx_emb).cpu().numpy()
        max_sims = np.max(sim_mtx, axis=1)
        faithful = (max_sims >= sentence_threshold).sum()
        return float(faithful / max(1, len(ans_sents)))
    except Exception as e:
        log(f"Error in faithfulness scoring: {e}")
        return 0.0

# NLG metrics wrapper
def compute_nlg_metrics(pred, ref):
    # expects strings
    try:
        # BLEU expects tokenized list of references and hypothesis tokens
        bleu_res = bleu_metric.compute(predictions=[pred.split()], references=[[ref.split()]])
        rouge_res = rouge_metric.compute(predictions=[pred], references=[ref])
        bert_res = bertscore_metric.compute(predictions=[pred], references=[ref], lang="en")
        return {"bleu": bleu_res.get("bleu", 0.0), "rouge": rouge_res, "bertscore": bert_res}
    except Exception as e:
        log(f"NLG metrics error: {e}")
        return {}

# %%
# Cell 9/11 - Full RAG pipeline orchestration

def rag_pipeline_with_metrics(query, retrieve_k=20, rerank_k=5, context_chunks=3, strategy="generate", log_diagnostics=False):
    log(f"Processing query: {query[:120]}...")
    candidate_indices, hyde_txt = retrieve_with_hyde(query, k=retrieve_k)
    reranked_texts = rerank_chunks(query, candidate_indices, top_k=rerank_k, use_cross_encoder=True)
    selected_contexts = reranked_texts[:context_chunks]
    if log_diagnostics:
        print("Selected contexts:")
        for i, c in enumerate(selected_contexts):
            print(i, c[:250].replace("\n", " "), "...")
    # Answer generation
    if strategy == "extract_then_summarize":
        answer = extract_then_summarize(query, selected_contexts, top_sents=8)
    else:
        answer = generate_answer(query, selected_contexts, max_new_tokens=220)

    # Compute metrics
    retrieval_score = retrieval_relevance_score(query, top_k=retrieve_k)
    completeness = answer_completeness_score(answer, selected_contexts)
    faith = faithfulness_score(answer, selected_contexts)
    composite = 0.4 * retrieval_score + 0.3 * completeness + 0.3 * faith

    return {
        "query": query,
        "answer": answer,
        "context": selected_contexts,
        "retrieval_score": retrieval_score,
        "completeness_score": completeness,
        "faithfulness_score": faith,
        "composite_score": composite,
        "hyde_answer": hyde_txt
    }

log("RAG pipeline ready.")
# Out:
# [17:18:42] RAG pipeline ready.

# %%
# Cell 10/11 - Quick test function
def test_pipeline(queries=None, strategy="generate", verbose=True):
    if queries is None:
        queries = ["Management of BI-RADS categories (0–6): what each means and recommended actions."]
        ["List key components of the first prenatal visit: labs, ultrasound timing, and risk assessment."]
        ["Define preeclampsia and severe features; outline diagnosis and acute management."]
        ["Screening and management approach for gestational diabetes: timing, tests, and treatment thresholds."]
        
    results = []
    for q in queries:
        try:
            r = rag_pipeline_with_metrics(q, retrieve_k=20, rerank_k=5, context_chunks=3, strategy=strategy, log_diagnostics=True)
            results.append(r)
            if verbose:
                print("\n" + "="*80)
                print("Q:", r["query"])
                print("\nHyDE (short):", r["hyde_answer"][:200])
                print("\nAnswer:\n", r["answer"])
                print("\nScores: Retrieval=%.3f  Completeness=%.3f  Faithfulness=%.3f  Composite=%.3f" % (
                    r["retrieval_score"], r["completeness_score"], r["faithfulness_score"], r["composite_score"]
                ))
        except Exception as e:
            print("Error:", e)
    return results

# run quick test
sample_results = test_pipeline()
# Out:
# [17:18:42] Processing query: Management of BI-RADS categories (0–6): what each means and recommended actions....
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Selected contexts:
# 0 The availability and usage of gender-responsive WASH (Water, Sanitation, and Hygiene) facilities are crucial for menstrual hygiene management (MHM). Let's break down what that means and the current realities. **What are Gender-Responsive WASH Facilit ...
# 1 This helps to identify any abnormalities or cancerous cells. **3. Management Strategies:** Once the cause is identified, we can discuss appropriate management options. ...
# 2 **While awaiting your answers, let's discuss immediate actions:**  * **Keep track of your bleeding. **  Use a menstrual diary to note the amount and duration of your bleeding. This will be invaluable for your assessment and future management. ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ================================================================================
# Q: Management of BI-RADS categories (0–6): what each means and recommended actions.
#
# HyDE (short): The management of the category 3 lesions is based on the results of the biopsy, while for the other categories it depends on the clinical context. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREE
#
# Answer:
#  It is not possible to distinguish between normal and abnormal findings on ultrasound.
#
# Scores: Retrieval=0.724  Completeness=0.000  Faithfulness=0.000  Composite=0.290

# %%
# Cell 11/11 - Evaluate on a small test sample and save outputs
def evaluate_on_testset(test_data, sample_size=20, strategy="generate"):
    log(f"Evaluating on {sample_size} test samples...")
    results = []
    for i, sample in enumerate(test_data[:sample_size]):
        try:
            r = rag_pipeline_with_metrics(sample['question'], strategy=strategy)
            r['ground_truth'] = sample['answer']
            # optional NLG metrics
            r['nlg'] = compute_nlg_metrics(r['answer'], sample['answer'])
            results.append(r)
            if (i+1) % 5 == 0:
                log(f"Processed {i+1}/{sample_size}")
        except Exception as e:
            log(f"Error on sample {i}: {e}")
            continue
    # print summary
    if results:
        print("\n" + "="*80)
        print("EVALUATION RESULTS:")
        print("Average Retrieval Score: %.3f" % np.mean([x['retrieval_score'] for x in results]))
        print("Average Completeness Score: %.3f" % np.mean([x['completeness_score'] for x in results]))
        print("Average Faithfulness Score: %.3f" % np.mean([x['faithfulness_score'] for x in results]))
        print("Average Composite Score: %.3f" % np.mean([x['composite_score'] for x in results]))
        # optionally save to disk
        with open("eval_results.pkl", "wb") as f:
            pickle.dump(results, f)
        log("Saved eval_results.pkl")
    return results

# run evaluation on a small sample
eval_results = evaluate_on_testset(test_data, sample_size=10, strategy="generate")
# Out:
# [17:18:48] Evaluating on 10 test samples...
# [17:18:48] Processing query: What are the specific instructions for washing and storing cloth menstrual pads?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:18:52] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['Do', 'you', 'wash', ..., 'used', 'cloth', 'pads?'],
# Input references: [['Washing', 'and', 'storing', 'cloth', 'menstrual', 'pads', 'correctly', 'is', 'crucial', 'for', 'hygiene', 'and', 'preventing', 'infections.', "Here's", 'a', 'detailed', 'guide', 'based', 'on', 'best', 'practices', 'and', 'hygiene', 'standards:', '**1.', 'Pre-Wash', 'Treatment:**', '*', '**Immediately', 'after', 'use:**', 'Rinse', 'your', 'used', 'pad', 'thoroughly', 'under', 'cold', 'running', 'water.', 'This', 'removes', 'the', 'bulk', 'of', 'menstrual', 'blood', 'and', 'prevents', 'staining.', 'The', 'colder', 'water', 'helps', 'prevent', 'the', 'blood', 'from', 'setting', 'into', 'the', 'fabric.', 'You', 'can', 'use', 'a', 'small', 'basin', 'or', 'even', 'your', 'toilet', 'to', 'rinse.', 'If', "you're", 'away', 'from', 'home,', 'a', 'sealed,', 'leak-proof', 'bag', 'is', 'appropriate', 'for', 'transport', 'until', 'you', 'can', 'rinse', 'the', 'pad.', '*', '**Spot', 'Treatment', '(Optional):**', 'For', 'stubborn', 'stains,', 'you', 'can', 'apply', 'a', 'stain', 'remover', 'designed', 'for', 'blood', '(oxygen-based', 'bleaches', 'are', 'generally', 'safe', 'and', 'effective;', 'avoid', 'chlorine', 'bleach)', 'before', 'rinsing.', 'Let', 'it', 'sit', 'for', 'a', 'few', 'minutes', 'before', 'rinsing.', '**2.', 'Washing:**', '*', '**Machine', 'Wash:**', 'This', 'is', 'the', 'most', 'effective', 'method.', 'Place', 'your', 'pads', 'in', 'a', 'mesh', 'laundry', 'bag', '(to', 'prevent', 'them', 'from', 'getting', 'caught', 'and', 'damaged)', 'and', 'wash', 'them', 'in', 'hot', 'water', '(at', 'least', '60°C/140°F)', 'with', 'your', 'regular', 'laundry', 'detergent.', 'Avoid', 'fabric', 'softener,', 'as', 'it', 'can', 'reduce', 'absorbency.', 'A', 'second', 'rinse', 'cycle', 'is', 'highly', 'recommended.', '*', '**Hand', 'Wash', '(less', 'effective):**', 'If', 'you', 'prefer,', 'you', 'can', 'hand', 'wash', 'your', 'pads', 'in', 'hot,', 'soapy', 'water.', 'Again,', 'thorough', 'rinsing', 'is', 'essential', 'to', 'remove', 'all', 'traces', 'of', 'blood', 'and', 'detergent.', '**3.', 'Drying:**', '*', '**Drying:**', 'Dry', 'your', 'pads', 'completely.', 'This', 'is', 'crucial', 'for', 'hygiene.', 'You', 'can', 'either', 'machine', 'dry', 'on', 'a', 'low', 'heat', 'setting', 'or', 'air', 'dry', 'them', 'in', 'direct', 'sunlight.', 'Sunlight', 'acts', 'as', 'a', 'natural', 'disinfectant.', 'Make', 'sure', 'the', 'pads', 'are', 'completely', 'dry', 'before', 'storing', 'to', 'prevent', 'the', 'growth', 'of', 'mold', 'or', 'bacteria.', '**4.', 'Storing:**', '*', '**Clean', '&', 'Dry', 'Storage:**', 'Store', 'your', 'clean,', 'dry', 'pads', 'in', 'a', 'clean,', 'dry,', 'and', 'well-ventilated', 'place,', 'such', 'as', 'a', 'dedicated', 'container,', 'or', 'a', 'breathable', 'bag.', 'Avoid', 'plastic', 'bags', 'as', 'they', 'trap', 'moisture.', '*', '**Frequency', 'of', 'Washing:**', 'Wash', 'your', 'pads', 'after', 'each', 'use,', 'or', 'at', 'least', 'once', 'daily', 'if', 'you’re', 'using', 'multiple', 'pads.', '**Important', 'Considerations:**', '*', '**Material:**', 'The', 'type', 'of', 'fabric', 'used', 'in', 'your', 'pads', 'affects', 'the', 'washing', 'instructions.', 'Always', 'check', 'the', 'manufacturer’s', 'care', 'label', 'for', 'specific', 'recommendations.', 'Many', 'modern', 'cloth', 'pads', 'are', 'made', 'of', 'materials', 'designed', 'to', 'withstand', 'repeated', 'hot', 'washes.', '*', '**Hygiene:**', 'Always', 'wash', 'your', 'hands', 'thoroughly', 'before', 'and', 'after', 'handling', 'your', 'used', 'or', 'clean', 'pads.', 'Proper', 'hygiene', 'practices', 'throughout', 'the', 'entire', 'process', 'are', 'essential', 'to', 'prevent', 'infection.', '*', '**Sustainability:**', 'Consider', 'using', 'eco-friendly', 'detergents', 'and', 'avoiding', 'excessive', 'heat', 'drying', 'to', 'minimize', 'your', 'environmental', 'impact.', 'Following', 'these', 'steps', 'will', 'ensure', 'your', 'cloth', 'menstrual', 'pads', 'remain', 'clean,', 'hygienic,', 'and', 'effective', 'for', 'extended', 'use,', 'cont ...
# [17:18:52] Processing query: How does age influence my menstrual cycle?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:18:56] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ["I'm", '6', '0', ..., 'and', 'night', 'sweats.'],
# Input references: [['The', 'age-related', 'changes', 'in', 'your', 'menstrual', 'cycle', 'are', 'significant', 'and', 'occur', 'in', 'predictable', 'stages,', 'primarily', 'influenced', 'by', 'hormonal', 'fluctuations.', "Let's", 'break', 'down', 'the', 'key', 'phases:', '**Puberty', '(Menarche):**', 'The', 'onset', 'of', 'menstruation,', 'typically', 'between', '11', 'and', '15', 'years', 'old,', 'marks', 'the', 'beginning.', 'Initial', 'cycles', 'are', 'often', 'irregular,', 'due', 'to', 'the', 'developing', 'hypothalamic-pituitary-ovarian', '(HPO)', 'axis', 'still', 'establishing', 'its', 'rhythm.', 'Ovulation', 'may', 'be', 'infrequent', 'or', 'absent', 'in', 'these', 'early', 'years.', 'This', 'irregularity', 'is', 'normal', 'and', 'usually', 'resolves', 'within', 'a', 'few', 'years.', '**Reproductive', 'Years', '(Adult', 'Cycle):**', 'Once', 'the', 'HPO', 'axis', 'matures,', 'your', 'cycle', 'typically', 'settles', 'into', 'a', '21-35', 'day', 'rhythm,', 'with', 'the', 'average', 'being', '28', 'days.', 'This', 'regularity', 'reflects', 'the', 'predictable', 'hormonal', 'cascade', 'leading', 'to', 'ovulation', 'and', 'menstruation.', 'The', 'length', 'and', 'flow', 'can', 'vary', 'slightly', 'from', 'cycle', 'to', 'cycle,', 'which', 'is', 'still', 'considered', 'normal,', 'provided', 'the', 'variation', 'stays', 'within', 'a', 'reasonable', 'range.', '**Peri-menopause', '(Transition', 'Phase):**', 'This', 'period,', 'leading', 'up', 'to', 'menopause,', 'typically', 'starts', 'in', 'the', '40s,', 'although', 'it', 'can', 'begin', 'earlier', 'or', 'later.', 'The', 'ovaries', 'begin', 'to', 'produce', 'less', 'estrogen', 'and', 'progesterone,', 'resulting', 'in', 'noticeable', 'changes:', '*', '**Irregular', 'Cycles:**', 'This', 'is', 'the', 'hallmark', 'of', 'peri-menopause.', 'Cycles', 'become', 'unpredictable', '–', 'shorter', 'or', 'longer,', 'heavier', 'or', 'lighter,', 'with', 'skipped', 'periods', 'common.', 'The', 'reason', 'for', 'this', 'is', 'the', 'fluctuating', 'hormone', 'production,', 'causing', 'inconsistent', 'follicle', 'growth', 'and', 'ovulation.', '*', '**Cycle', 'Length', 'Changes:**', 'The', 'variation', 'in', 'cycle', 'length', 'is', 'often', 'quite', 'extreme', 'during', 'peri-menopause.', 'You', 'might', 'experience', 'very', 'short', 'cycles', '(less', 'than', '21', 'days)', 'or', 'very', 'long', 'cycles', '(more', 'than', '35', 'days),', 'or', 'a', 'combination', 'of', 'both.', '*', '**Changes', 'in', 'Bleeding:**', 'Heavier', 'bleeding', '(menorrhagia)', 'or', 'lighter', 'bleeding', '(hypomenorrhea)', 'than', 'usual', 'can', 'occur.', 'Spotting', 'between', 'periods', 'is', 'also', 'common.', '**Menopause:**', 'Menopause', 'is', 'defined', 'as', 'the', 'cessation', 'of', 'menstruation', 'for', '12', 'consecutive', 'months.', 'The', 'ovaries', 'cease', 'producing', 'significant', 'amounts', 'of', 'estrogen', 'and', 'progesterone.', 'Hormonal', 'fluctuations', 'end,', 'and', 'menstrual', 'periods', 'stop', 'permanently.', '**Post-Menopause:**', 'After', 'menopause,', 'bleeding', 'should', 'cease', 'entirely.', 'Any', 'postmenopausal', 'bleeding', 'requires', 'immediate', 'medical', 'attention', 'as', 'it', 'could', 'indicate', 'a', 'serious', 'underlying', 'condition,', 'such', 'as', 'endometrial', 'hyperplasia', 'or', 'cancer.', '**Important', 'Considerations:**', '*', '**Individual', 'Variation:**', "It's", 'crucial', 'to', 'remember', 'that', 'every', 'woman', 'experiences', 'these', 'age-related', 'changes', 'differently.', "There's", 'a', 'wide', 'range', 'of', 'normal', 'variation.', '*', '**Medical', 'Advice:**', 'If', "you're", 'experiencing', 'significant', 'changes', 'in', 'your', 'menstrual', 'cycle,', 'particularly', 'irregular', 'bleeding,', 'heavy', 'bleeding,', 'or', 'prolonged', 'absence', 'of', 'periods', 'outside', 'of', 'the', 'expected', 'peri-menopausal', 'timeframe,', "it's", 'essential', 'to', 'schedule', 'a', 'check-up', 'with', 'me.', "We'll", 'review', 'your', 'specific', ...
# [17:18:56] Processing query: What are the common symptoms of PID and how is it diagnosed?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:01] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['Pelvic', 'inflammatory', 'disease', ..., 'and', 'Chlamydia', 'trachomatis.'],
# Input references: [['Pelvic', 'Inflammatory', 'Disease', '(PID)', 'is', 'a', 'serious', 'infection', 'of', 'the', 'female', 'reproductive', 'organs.', "It's", 'crucial', 'to', 'understand', 'that', 'PID', "isn't", 'a', 'single', 'disease', 'but', 'rather', 'a', 'spectrum', 'of', 'infections', 'that', 'can', 'involve', 'the', 'uterus,', 'fallopian', 'tubes,', 'and', 'ovaries.', 'The', 'symptoms', 'can', 'vary', 'greatly,', 'and', 'unfortunately,', 'many', 'women', 'experience', 'no', 'symptoms', 'at', 'all,', 'making', 'early', 'diagnosis', 'challenging.', 'This', 'asymptomatic', 'presentation', 'is', 'precisely', 'why', 'regular', 'checkups', 'with', 'a', 'gynecologist', 'are', 'so', 'vital.', '**Common', 'Symptoms:**', 'While', 'not', 'every', 'woman', 'will', 'experience', 'all', 'of', 'these,', 'some', 'of', 'the', 'most', 'frequently', 'reported', 'symptoms', 'of', 'PID', 'include:', '*', '**Lower', 'abdominal', 'pain:**', 'This', 'is', 'the', 'most', 'common', 'symptom', 'and', 'can', 'range', 'from', 'mild', 'cramping', 'to', 'severe,', 'sharp', 'pain.', 'The', 'pain', 'may', 'be', 'constant', 'or', 'intermittent', 'and', 'can', 'worsen', 'with', 'movement', 'or', 'sexual', 'activity.', '*', '**Abnormal', 'vaginal', 'discharge:**', 'This', 'discharge', 'is', 'often', 'yellow', 'or', 'greenish,', 'foul-smelling,', 'and', 'may', 'be', 'heavier', 'than', 'usual.', '*', '**Fever', 'and', 'chills:**', 'Systemic', 'infection', 'often', 'manifests', 'as', 'fever', 'and', 'chills.', '*', '**Pain', 'during', 'sexual', 'intercourse', '(dyspareunia):**', 'The', 'inflammation', 'and', 'infection', 'can', 'make', 'sexual', 'activity', 'extremely', 'painful.', '*', '**Abnormal', 'uterine', 'bleeding:**', 'This', 'can', 'include', 'heavier,', 'lighter,', 'or', 'more', 'irregular', 'bleeding', 'than', 'usual.', '*', '**Painful', 'urination', '(dysuria):**', 'This', 'is', 'due', 'to', 'the', 'proximity', 'of', 'the', 'infected', 'organs', 'to', 'the', 'urethra.', '*', '**Lower', 'back', 'pain:**', 'This', 'pain', 'can', 'radiate', 'from', 'the', 'pelvic', 'area.', '*', '**Nausea', 'and', 'vomiting:**', 'In', 'more', 'severe', 'cases,', 'nausea', 'and', 'vomiting', 'can', 'accompany', 'the', 'pelvic', 'pain.', '*', '**Fatigue:**', 'General', 'tiredness', 'and', 'weakness', 'are', 'common', 'symptoms', 'of', 'infection.', '**Important', 'Note:**', 'The', 'absence', 'of', 'symptoms', 'does', '*not*', 'rule', 'out', 'PID.', 'Many', 'women,', 'particularly', 'those', 'with', 'mild', 'infections,', 'have', 'no', 'noticeable', 'symptoms.', 'This', 'underscores', 'the', 'critical', 'importance', 'of', 'regular', 'gynecological', 'exams.', '**Diagnosis:**', 'Diagnosing', 'PID', 'can', 'be', 'tricky', 'as', 'the', 'symptoms', 'often', 'overlap', 'with', 'those', 'of', 'other', 'conditions.', 'A', 'thorough', 'evaluation', 'involves', 'a', 'combination', 'of', 'approaches:', '*', '**Pelvic', 'Exam:**', 'A', 'physical', 'examination', 'will', 'assess', 'for', 'tenderness', 'in', 'the', 'abdomen', 'and', 'pelvis.', 'Your', 'doctor', 'will', 'palpate', 'your', 'lower', 'abdomen', 'to', 'check', 'for', 'tenderness', 'and', 'masses.', 'A', 'speculum', 'exam', 'will', 'assess', 'the', 'cervix', 'and', 'vagina', 'for', 'inflammation', 'and', 'discharge.', '*', '**Lab', 'Tests:**', 'These', 'are', 'essential', 'for', 'confirmation.', 'They', 'typically', 'include:', '*', '**Vaginal', 'swab', 'for', 'culture', 'and', 'sensitivity:**', 'This', 'test', 'identifies', 'the', 'causative', 'organism', 'and', 'helps', 'guide', 'antibiotic', 'treatment.', 'However,', "it's", 'important', 'to', 'note', 'that', 'the', 'causative', 'organism', "isn't", 'always', 'found,', 'even', 'in', 'cases', 'of', 'PID.', '*', '**White', 'blood', 'cell', 'count', '(WBC):**', 'An', 'elevated', 'WBC', 'count', 'suggests', 'infection.', '*', '**Tests', 'for', 'sexually', 'transmitted', 'infections', '(STIs):**', 'Many', 'cases', 'of', 'PID', 'are', 'caused', 'by', 'STIs', 'like', 'Chl ...
# [17:19:01] Processing query: I'm concerned about my risk of developing certain gynecological cancers. How can I reduce my risk and what screenings sh...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:13] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['Cervical', 'cancer', 'screening', ..., 'hypopharynx,', 'and', 'nasopharynx.'],
# Input references: [["It's", 'commendable', 'that', "you're", 'proactive', 'about', 'your', 'gynecological', 'health.', "Let's", 'discuss', 'your', 'concerns', 'about', 'gynecological', 'cancers', 'and', 'how', 'to', 'mitigate', 'your', 'risk.', 'Several', 'factors', 'influence', 'the', 'risk', 'of', 'developing', 'these', 'cancers,', 'and', 'thankfully,', 'many', 'are', 'modifiable.', 'The', 'most', 'common', 'gynecological', 'cancers', 'include:', '*', '**Cervical', 'cancer:**', 'Human', 'papillomavirus', '(HPV)', 'infection', 'is', 'the', 'primary', 'cause', 'of', 'cervical', 'cancer.', 'Regular', 'screening', 'is', 'crucial.', 'The', 'Pap', 'smear', 'and', 'HPV', 'test', 'are', 'highly', 'effective', 'in', 'detecting', 'precancerous', 'changes,', 'allowing', 'for', 'early', 'intervention', 'and', 'prevention.', 'The', 'current', 'guidelines', 'generally', 'recommend', 'beginning', 'Pap', 'smears', 'around', 'age', '21,', 'even', 'if', 'you', 'are', 'sexually', 'active.', 'The', 'frequency', 'of', 'testing', 'varies', 'based', 'on', 'age', 'and', 'individual', 'risk', 'factors,', 'so', "let's", 'discuss', 'your', 'specific', 'situation.', 'Vaccination', 'against', 'HPV', 'is', 'also', 'highly', 'recommended', 'before', 'becoming', 'sexually', 'active', 'to', 'prevent', 'infection.', '*', '**Endometrial', 'cancer', '(cancer', 'of', 'the', 'uterine', 'lining):**', 'Obesity,', 'prolonged', 'estrogen', 'exposure', '(unopposed', 'by', 'progesterone,', 'like', 'in', 'conditions', 'where', 'ovulation', "doesn't", 'occur', 'regularly),', 'and', 'certain', 'genetic', 'conditions', 'increase', 'the', 'risk.', 'Maintaining', 'a', 'healthy', 'weight,', 'regular', 'exercise,', 'and', 'a', 'balanced', 'diet', 'can', 'help', 'reduce', 'risk.', 'If', 'you', 'experience', 'abnormal', 'uterine', 'bleeding,', "it's", 'essential', 'to', 'seek', 'evaluation', 'promptly.', '*', '**Ovarian', 'cancer:**', 'This', 'cancer', 'is', 'notoriously', 'difficult', 'to', 'detect', 'early,', 'as', 'symptoms', 'are', 'often', 'vague', 'and', 'can', 'mimic', 'other', 'conditions.', 'Family', 'history', 'of', 'ovarian', 'cancer,', 'BRCA', 'gene', 'mutations,', 'and', 'certain', 'genetic', 'syndromes', 'significantly', 'increase', 'the', 'risk.', "There's", 'no', 'single', 'definitive', 'screening', 'test', 'for', 'ovarian', 'cancer,', 'but', 'regular', 'pelvic', 'exams', 'and', 'transvaginal', 'ultrasounds,', 'especially', 'for', 'high-risk', 'individuals,', 'can', 'be', 'beneficial.', 'Understanding', 'your', 'family', 'history', 'is', 'crucial', 'in', 'determining', 'the', 'appropriate', 'screening', 'strategy.', '*', '**Vulvar', 'and', 'vaginal', 'cancers:**', 'Similar', 'to', 'cervical', 'cancer,', 'HPV', 'infection', 'is', 'a', 'major', 'risk', 'factor.', 'Regular', 'self-exams', 'and', 'prompt', 'evaluation', 'of', 'any', 'unusual', 'lesions', 'or', 'persistent', 'changes', 'are', 'important.', '**Reducing', 'Your', 'Risk:**', 'Several', 'lifestyle', 'choices', 'can', 'significantly', 'reduce', 'your', 'risk', 'of', 'developing', 'gynecological', 'cancers:', '*', '**HPV', 'Vaccination:**', 'This', 'vaccine', 'protects', 'against', 'the', 'most', 'common', 'HPV', 'strains', 'that', 'cause', 'cervical,', 'vulvar,', 'and', 'vaginal', 'cancers.', "It's", 'most', 'effective', 'when', 'given', 'before', 'sexual', 'activity', 'begins.', '*', '**Maintain', 'a', 'Healthy', 'Weight:**', 'Obesity', 'increases', 'the', 'risk', 'of', 'endometrial', 'and', 'ovarian', 'cancers.', 'A', 'balanced', 'diet,', 'regular', 'exercise,', 'and', 'achieving', 'a', 'healthy', 'BMI', 'are', 'vital.', '*', '**Safe', 'Sex', 'Practices:**', 'Limiting', 'the', 'number', 'of', 'sexual', 'partners', 'and', 'using', 'barrier', 'methods', 'like', 'condoms', 'can', 'help', 'prevent', 'HPV', 'transmission.', '*', '**Regular', 'Exercise:**', 'Physical', 'activity', 'reduces', 'the', 'risk', 'of', 'several', 'cancers,', 'including', 'endometrial', 'cancer.', '*', '**Avoid', 'Smoking:**', 'Smoki ...
# [17:19:13] Processing query: What are some tips for having sex on my period?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:23] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['No"', '1', '4.', ..., 'talk', 'to', 'someone'],
# Input references: [['Having', 'sex', 'during', 'your', 'period', 'is', 'perfectly', 'safe', 'and', 'can', 'be', 'enjoyable', 'for', 'many', 'couples,', 'but', 'it', 'does', 'require', 'some', 'adjustments', 'and', 'considerations.', "Here's", 'what', 'you', 'should', 'know:', '**Preparation', 'and', 'Comfort:**', '*', '**Hygiene:**', 'This', 'is', 'paramount.', 'Consider', 'showering', 'or', 'washing', 'beforehand', 'to', 'feel', 'fresh', 'and', 'clean.', 'Having', 'some', 'extra', 'towels', 'handy', 'is', 'also', 'a', 'good', 'idea.', '*', '**Protection:**', 'Always', 'use', 'barrier', 'methods', 'like', 'condoms', 'to', 'prevent', 'pregnancy', 'and', 'the', 'spread', 'of', 'sexually', 'transmitted', 'infections', '(STIs).', 'This', 'is', 'crucial', 'regardless', 'of', 'your', 'cycle', 'phase.', '*', '**Positioning:**', 'Experiment', 'to', 'find', 'positions', 'that', 'are', 'comfortable', 'for', 'both', 'partners.', 'Gravity', 'can', 'be', 'your', 'friend;', 'positions', 'where', "you're", 'on', 'top', 'might', 'reduce', 'mess.', '*', '**Menstrual', 'cup', 'or', 'tampon:**', 'For', 'comfort', 'and', 'to', 'minimize', 'mess,', 'using', 'a', 'menstrual', 'cup', 'or', 'tampon', 'is', 'highly', 'recommended', 'during', 'intercourse.', 'Remember', 'to', 'remove', 'it', 'beforehand.', 'A', 'menstrual', 'disc', 'might', 'also', 'be', 'a', 'good', 'option,', 'as', 'it', 'sits', 'lower', 'than', 'a', 'tampon.', '*', '**Linens:**', 'Protecting', 'your', 'bedsheets', 'with', 'a', 'dark-colored', 'towel', 'is', 'a', 'wise', 'precaution.', '**Addressing', 'Concerns:**', '*', '**Mess:**', "It's", 'natural', 'to', 'be', 'concerned', 'about', 'blood.', 'The', 'above', 'suggestions', 'can', 'significantly', 'minimize', 'this.', "Don't", 'let', 'this', 'deter', 'you', 'from', 'enjoying', 'intimacy.', '*', '**Cramps:**', 'For', 'some,', 'sex', 'can', 'actually', 'relieve', 'menstrual', 'cramps', 'due', 'to', 'the', 'release', 'of', 'endorphins.', 'However,', 'if', 'cramps', 'are', 'severe,', 'focus', 'on', 'comfort', 'and', 'relaxation,', 'and', 'perhaps', 'postpone', 'intimacy.', '*', '**Changes', 'in', 'Libido:**', 'Hormonal', 'fluctuations', 'during', 'menstruation', 'can', 'affect', 'libido.', 'Open', 'communication', 'with', 'your', 'partner', 'is', 'key;', 'if', 'either', 'of', 'you', "isn't", 'feeling', 'it,', "that's", 'perfectly', 'acceptable.', 'Focus', 'on', 'intimacy', 'and', 'connection', 'that', 'goes', 'beyond', 'intercourse.', '*', '**Infection', 'Risk:**', 'The', 'vagina', 'is', 'self-cleaning.', 'While', 'the', 'slight', 'increase', 'in', 'blood', 'flow', 'during', 'your', 'period', "doesn't", 'significantly', 'increase', 'the', 'risk', 'of', 'infection', 'when', 'practicing', 'safe', 'sex,', 'maintaining', 'good', 'hygiene', 'remains', 'important.', '**Important', 'Considerations:**', '*', '**Underlying', 'conditions:**', 'If', 'you', 'have', 'any', 'underlying', 'gynecological', 'conditions', 'such', 'as', 'endometriosis,', 'pelvic', 'inflammatory', 'disease', '(PID),', 'or', 'heavy', 'bleeding', '(menorrhagia),', 'it’s', 'important', 'to', 'discuss', 'with', 'me', 'if', 'intercourse', 'during', 'your', 'period', 'is', 'suitable', 'for', 'you.', 'While', 'generally', 'safe,', 'specific', 'conditions', 'might', 'necessitate', 'cautious', 'consideration.', '*', '**Pain:**', 'If', 'sex', 'is', 'consistently', 'painful', 'during', 'your', 'period,', 'please', 'schedule', 'an', 'appointment', 'so', 'we', 'can', 'investigate', 'the', 'cause.', 'Painful', 'intercourse', 'is', 'not', 'normal', 'and', 'warrants', 'investigation.', 'Open', 'communication', 'with', 'your', 'partner', 'is', 'crucial.', 'Discuss', 'your', 'concerns,', 'preferences,', 'and', 'comfort', 'levels', 'to', 'ensure', 'a', 'positive', 'and', 'enjoyable', 'experience.', 'Remember,', 'intimacy', 'extends', 'beyond', 'intercourse,', 'and', 'exploring', 'other', 'forms', 'of', 'closeness', 'during', 'your', 'period', 'can', 'be', 'equally', 'fulfilling.']]
# [17:19:23] Processed 5/10
# [17:19:23] Processing query: Can you explain how Depo-Provera affects my menstrual cycle and fertility?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:26] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['The', 'effects', 'of', ..., 'fertility', 'are', 'temporary.'],
# Input references: [['Depo-Provera,', 'or', 'medroxyprogesterone', 'acetate,', 'is', 'a', 'long-acting,', 'injectable', 'contraceptive.', 'Its', 'impact', 'on', 'your', 'menstrual', 'cycle', 'and', 'fertility', 'is', 'significant', 'and', 'predictable,', 'though', 'the', 'experience', 'can', 'vary', 'slightly', 'from', 'woman', 'to', 'woman.', '**Effect', 'on', 'Menstrual', 'Cycle:**', 'Depo-Provera', 'works', 'primarily', 'by', 'suppressing', 'ovulation.', 'This', 'means', 'your', 'ovaries', "don't", 'release', 'an', 'egg,', 'preventing', 'pregnancy.', 'The', 'hormonal', 'changes', 'also', 'lead', 'to', 'a', 'thinning', 'of', 'the', 'uterine', 'lining,', 'making', 'it', 'less', 'hospitable', 'for', 'implantation.', 'As', 'a', 'result,', 'many', 'women', 'experience', 'a', 'significant', 'reduction', 'in', 'menstrual', 'bleeding', 'over', 'time.', 'Some', 'women', 'may', 'experience', 'lighter', 'periods,', 'less', 'frequent', 'periods', '(oligomenorrhea),', 'or', 'even', 'the', 'complete', 'absence', 'of', 'periods', '(amenorrhea).', 'This', 'amenorrhea', 'is', 'often', 'considered', 'a', 'positive', 'side', 'effect', 'by', 'many', 'users,', 'as', 'it', 'eliminates', 'the', 'inconvenience', 'and', 'discomfort', 'of', 'monthly', 'bleeding.', 'However,', "it's", 'important', 'to', 'note', 'that', 'irregular', 'bleeding,', 'spotting,', 'or', 'heavier', 'bleeding', 'can', 'occur,', 'especially', 'during', 'the', 'first', 'few', 'months', 'after', 'starting', 'Depo-Provera.', 'The', 'changes', 'in', 'your', 'cycle', "aren't", 'immediate.', 'It', 'usually', 'takes', 'a', 'few', 'months', 'for', 'your', 'body', 'to', 'fully', 'adjust', 'to', 'the', 'hormone.', "Don't", 'be', 'alarmed', 'if', 'your', 'bleeding', 'pattern', 'remains', 'erratic', 'for', 'the', 'first', 'few', 'cycles.', '**Effect', 'on', 'Fertility:**', 'The', 'primary', 'mechanism', 'by', 'which', 'Depo-Provera', 'prevents', 'pregnancy', 'is', 'its', 'suppression', 'of', 'ovulation.', 'However,', "it's", 'crucial', 'to', 'understand', 'that', 'the', 'return', 'of', 'fertility', 'after', 'stopping', 'Depo-Provera', 'can', 'be', 'delayed.', 'While', 'some', 'women', 'regain', 'fertility', 'quickly,', 'others', 'may', 'experience', 'a', 'delay', 'of', 'several', 'months,', 'or', 'even', 'more', 'than', 'a', 'year', 'in', 'some', 'cases.', 'The', 'length', 'of', 'this', 'delay', 'is', 'influenced', 'by', 'individual', 'factors', 'like', 'your', 'age', 'and', 'overall', 'health.', 'Therefore,', 'if', "you're", 'planning', 'a', 'pregnancy,', "it's", 'vital', 'to', 'discuss', 'your', 'timeline', 'with', 'me.', 'We', 'can', 'carefully', 'consider', 'your', 'individual', 'circumstances', 'and', 'create', 'a', 'plan', 'that', 'facilitates', 'your', 'desired', 'pregnancy', 'timing.', '**Important', 'Considerations:**', '*', '**Bone', 'Density:**', 'Long-term', 'use', 'of', 'Depo-Provera', 'has', 'been', 'linked', 'to', 'a', 'slight', 'decrease', 'in', 'bone', 'mineral', 'density.', 'This', 'is', 'generally', 'reversible', 'once', 'you', 'stop', 'injections,', 'but', 'regular', 'weight-bearing', 'exercise', 'and', 'a', 'calcium-rich', 'diet', 'can', 'mitigate', 'this', 'risk.', 'We', 'should', 'discuss', 'your', 'individual', 'risk', 'factors', 'and', 'monitor', 'your', 'bone', 'health', 'accordingly.', '*', '**Weight', 'Gain:**', 'Some', 'women', 'experience', 'weight', 'gain', 'while', 'using', 'Depo-Provera.', 'This', 'is', 'likely', 'due', 'to', 'hormonal', 'changes,', 'but', 'maintaining', 'a', 'healthy', 'diet', 'and', 'exercise', 'routine', 'can', 'help', 'manage', 'this.', '*', '**Mood', 'Changes:**', 'Mood', 'swings,', 'depression,', 'and', 'anxiety', 'are', 'potential', 'side', 'effects.', 'If', 'you', 'experience', 'any', 'significant', 'changes', 'in', 'your', 'mood,', "it's", 'crucial', 'to', 'discuss', 'these', 'with', 'me', 'immediately.', 'In', 'summary,', 'Depo-Provera', 'significantly', 'alters', 'your', 'menstrual', 'cycle', 'and', 'temporarily', 'suppresses', ' ...
# [17:19:26] Processing query: I'm going through perimenopause, and my periods are becoming erratic and heavier. What can help?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:31] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['Do', 'you', 'think', 'exercise', 'will', 'help?'],
# Input references: [["It's", 'completely', 'understandable', 'to', 'feel', 'concerned', 'about', 'erratic', 'and', 'heavier', 'periods', 'during', 'perimenopause.', 'This', 'is', 'a', 'common', 'experience', 'as', 'your', 'body', 'transitions', 'towards', 'menopause.', "Let's", 'discuss', 'some', 'ways', 'to', 'manage', 'these', 'symptoms.', 'The', 'hormonal', 'fluctuations', 'characteristic', 'of', 'perimenopause', '–', 'the', 'gradual', 'decline', 'in', 'estrogen', 'and', 'progesterone', '–', 'are', 'the', 'primary', 'culprits', 'behind', 'irregular', 'bleeding', 'and', 'heavier', 'flow.', 'Your', 'body', 'is', 'essentially', 'losing', 'its', 'synchronized', 'hormonal', 'dance,', 'resulting', 'in', 'unpredictable', 'shedding', 'of', 'the', 'uterine', 'lining.', '**Regarding', 'the', 'heavier', 'bleeding', '(menorrhagia):**', 'This', 'warrants', 'attention,', 'not', 'just', 'for', 'the', 'discomfort', 'and', 'inconvenience,', 'but', 'also', 'because', 'it', 'can', 'lead', 'to', 'anemia', 'if', 'left', 'unchecked.', 'We', 'need', 'to', 'explore', 'the', 'potential', 'causes', 'and', 'find', 'suitable', 'management', 'strategies.', 'While', "it's", 'often', 'simply', 'a', 'consequence', 'of', 'hormonal', 'shifts,', 'other', 'factors', 'should', 'be', 'ruled', 'out.', 'Here’s', 'what', 'we', 'can', 'consider:', '*', '**Lifestyle', 'modifications:**', 'These', 'can', 'sometimes', 'make', 'a', 'significant', 'difference.', 'Maintaining', 'a', 'healthy', 'weight', 'is', 'crucial', 'because', 'obesity', 'is', 'linked', 'to', 'heavier', 'bleeding.', 'Regular', 'exercise,', 'a', 'balanced', 'diet', 'rich', 'in', 'iron', '(to', 'combat', 'potential', 'anemia),', 'and', 'stress', 'reduction', 'techniques', '(yoga,', 'meditation,', 'deep', 'breathing)', 'are', 'all', 'beneficial.', '*', '**Medications:**', 'Several', 'options', 'exist', 'depending', 'on', 'the', 'severity', 'and', 'your', 'overall', 'health.', 'Nonsteroidal', 'anti-inflammatory', 'drugs', '(NSAIDs)', 'like', 'ibuprofen', 'can', 'help', 'reduce', 'pain', 'and', 'bleeding.', 'Tranexamic', 'acid', 'is', 'another', 'medication', 'that', 'can', 'specifically', 'reduce', 'menstrual', 'bleeding.', 'Hormonal', 'therapy', '(HT),', 'including', 'combined', 'estrogen-progesterone', 'or', 'estrogen', 'alone', '(if', "you've", 'had', 'a', 'hysterectomy),', 'is', 'often', 'highly', 'effective', 'in', 'regulating', 'periods', 'and', 'reducing', 'heavy', 'bleeding.', "We'll", 'need', 'to', 'discuss', 'your', 'individual', 'risk', 'factors', 'and', 'preferences', 'to', 'determine', 'if', 'HT', 'is', 'suitable', 'for', 'you.', 'Progesterone-only', 'therapies,', 'like', 'a', 'progesterone', 'IUD', '(intrauterine', 'device),', 'can', 'also', 'be', 'effective', 'in', 'regulating', 'bleeding', 'in', 'some', 'women.', '*', '**Other', 'interventions:**', 'If', 'medication', "isn't", 'enough,', 'or', 'if', 'other', 'underlying', 'conditions', 'are', 'suspected,', 'further', 'investigations', 'may', 'be', 'necessary.', 'A', 'thorough', 'pelvic', 'exam,', 'blood', 'tests', '(including', 'a', 'complete', 'blood', 'count', 'to', 'check', 'for', 'anemia),', 'and', 'potentially', 'an', 'ultrasound', 'to', 'assess', 'the', 'uterine', 'lining', 'may', 'be', 'considered', 'to', 'rule', 'out', 'other', 'problems', 'like', 'fibroids', 'or', 'polyps.', 'In', 'rare', 'cases,', 'endometrial', 'ablation', '(removal', 'of', 'the', 'uterine', 'lining)', 'or', 'hysterectomy', 'may', 'be', 'discussed', 'as', 'last', 'resort', 'options.', 'It’s', 'crucial', 'that', 'we', 'work', 'together', 'to', 'find', 'the', 'best', 'approach', 'for', '*you*.', 'Your', 'age,', 'overall', 'health,', 'other', 'medical', 'conditions,', 'and', 'your', 'preferences', 'will', 'all', 'influence', 'the', 'most', 'appropriate', 'management', 'strategy.', 'Please', 'schedule', 'a', 'follow-up', 'appointment', 'so', 'we', 'can', 'discuss', 'these', 'options', 'in', 'more', 'detail,', 'and', 'I', 'can', 'perform', 'a', 'proper', 'examination ...
# [17:19:31] Processing query: I'm interested in learning more about the fertile window.  Can you explain how it's defined and how long it lasts?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:36] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ["It's", 'a', 'very', ..., 'ends', 'with', 'fertilization.'],
# Input references: [['The', 'fertile', 'window', 'is', 'the', 'period', 'in', 'a', "woman's", 'menstrual', 'cycle', 'when', 'she', 'is', 'most', 'likely', 'to', 'conceive.', "It's", 'not', 'a', 'precisely', 'defined', 'timeframe', 'like,', 'say,', 'a', 'calendar', 'date,', 'because', 'individual', 'cycles', 'vary.', 'However,', 'we', 'can', 'pinpoint', 'it', 'with', 'reasonable', 'accuracy', 'based', 'on', 'understanding', 'ovulation.', '**Defining', 'the', 'Fertile', 'Window:**', 'The', 'fertile', 'window', 'encompasses', 'the', 'five', 'days', 'leading', 'up', 'to', 'ovulation,', 'including', 'the', 'day', 'of', 'ovulation', 'itself.', 'Sperm', 'can', 'survive', 'in', 'the', 'female', 'reproductive', 'tract', 'for', 'up', 'to', 'five', 'days,', 'and', 'the', 'egg', '(ovum)', 'lives', 'for', 'approximately', '24', 'hours', 'after', 'being', 'released.', 'Therefore,', 'sexual', 'intercourse', 'during', 'this', 'six-day', 'window', 'maximizes', 'the', 'chances', 'of', 'fertilization.', '**Determining', 'Ovulation:**', 'Pinpointing', 'ovulation', 'is', 'key', 'to', 'determining', 'the', 'fertile', 'window.', 'While', 'a', 'regular', '28-day', 'cycle', 'suggests', 'ovulation', 'around', 'day', '14,', 'this', 'is', 'just', 'an', 'average.', 'Ovulation', 'can', 'occur', 'anywhere', 'between', 'day', '11', 'and', 'day', '21', 'of', 'a', "woman's", 'cycle,', 'depending', 'on', 'cycle', 'length', 'and', 'individual', 'variations.', 'There', 'are', 'several', 'ways', 'to', 'track', 'ovulation:', '*', '**Basal', 'Body', 'Temperature', '(BBT):**', 'Your', 'BBT', 'rises', 'slightly', 'after', 'ovulation.', 'Tracking', 'this', 'daily', 'using', 'a', 'basal', 'thermometer', 'can', 'help', 'identify', 'the', 'day', 'of', 'ovulation', 'retrospectively.', "It's", 'not', 'ideal', 'for', 'predicting', 'the', 'fertile', 'window', '*in', 'advance*,', 'however.', '*', '**Cervical', 'Mucus:**', 'The', 'consistency', 'and', 'appearance', 'of', 'cervical', 'mucus', 'change', 'throughout', 'the', 'cycle.', 'Fertile', 'cervical', 'mucus', 'is', 'typically', 'clear,', 'stretchy,', 'and', 'slippery,', 'resembling', 'raw', 'egg', 'white.', 'Changes', 'in', 'mucus', 'can', 'help', 'pinpoint', 'the', 'approaching', 'ovulation.', '*', '**Ovulation', 'Predictor', 'Kits', '(OPKs):**', 'These', 'home', 'tests', 'detect', 'the', 'surge', 'in', 'luteinizing', 'hormone', '(LH)', 'that', 'happens', 'right', 'before', 'ovulation.', 'A', 'positive', 'test', 'indicates', 'ovulation', 'will', 'occur', 'within', '24-48', 'hours.', 'This', 'is', 'a', 'more', 'reliable', 'method', 'for', 'predicting', 'the', 'fertile', 'window.', '*', '**Tracking', 'App:**', 'Many', 'apps', 'combine', 'several', 'methods', '(cycle', 'length,', 'BBT,', 'cervical', 'mucus,', 'and', 'OPKs)', 'to', 'create', 'a', 'personalized', 'prediction', 'of', 'the', 'fertile', 'window.', 'They', 'can', 'be', 'helpful', 'but', 'remember', 'they', 'are', 'not', 'a', 'replacement', 'for', 'professional', 'medical', 'advice.', '*', '**Ultrasound:**', 'A', 'transvaginal', 'ultrasound', 'can', 'directly', 'visualize', 'the', 'ovaries', 'and', 'follicle', 'development,', 'accurately', 'pinpointing', 'ovulation.', 'This', 'is', 'usually', 'used', 'in', 'cases', 'of', 'infertility', 'or', 'when', 'more', 'precise', 'timing', 'is', 'necessary.', '**Length', 'of', 'the', 'Fertile', 'Window:**', 'While', 'the', 'most', 'fertile', 'period', 'is', 'those', 'six', 'days', '(five', 'before', 'ovulation,', 'plus', 'the', 'day', 'of', 'ovulation),', 'some', 'studies', 'suggest', 'a', 'slightly', 'wider', 'window', 'of', 'fertility,', 'potentially', 'extending', 'to', 'seven', 'or', 'even', 'eight', 'days.', 'This', 'is', 'because', 'sperm', 'viability', 'and', 'the', 'timing', 'of', 'egg', 'release', 'can', 'have', 'individual', 'variations.', 'However,', 'the', 'chances', 'of', 'conception', 'are', 'significantly', 'higher', 'during', 'the', 'primary', 'six-day', 'period.', 'Remember,', 'these', 'are', 'guidelines.', 'Ind ...
# [17:19:36] Processing query: How can I find a support group for women dealing with similar hormonal issues?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:39] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['There', 'are', 'many', ..., 'with', 'hormone', 'therapy.'],
# Input references: [['Finding', 'a', 'supportive', 'community', 'can', 'be', 'incredibly', 'beneficial', 'when', 'navigating', 'hormonal', 'issues.', 'There', 'are', 'several', 'avenues', 'you', 'can', 'explore,', 'depending', 'on', 'your', 'preferences', 'and', 'the', 'specifics', 'of', 'your', 'concerns.', '**Online', 'Communities:**', 'The', 'internet', 'offers', 'a', 'wealth', 'of', 'support,', 'offering', 'anonymity', 'and', 'accessibility.', 'Look', 'for', 'online', 'forums', 'or', 'groups', 'dedicated', 'to', 'specific', 'hormonal', 'conditions', '(e.g.,', 'PCOS,', 'endometriosis,', 'menopause).', 'Reliable', 'sources', 'include', 'reputable', 'organizations', 'like', 'the', 'National', 'Institutes', 'of', 'Health', '(NIH)', 'websites,', 'foundations', 'dedicated', 'to', 'specific', 'conditions', '(e.g.,', 'the', 'Endometriosis', 'Foundation', 'of', 'America),', 'or', 'large,', 'moderated', 'online', 'health', 'communities.', 'Remember', 'to', 'approach', 'online', 'information', 'critically;', 'verify', 'information', 'with', 'trusted', 'medical', 'sources.', '**Local', 'Support', 'Groups:**', 'Many', 'cities', 'and', 'towns', 'have', 'in-person', 'support', 'groups', 'for', 'women', 'facing', 'similar', 'health', 'challenges.', 'Your', "gynecologist's", 'office', 'might', 'be', 'able', 'to', 'provide', 'referrals', 'to', 'local', 'groups,', 'or', 'you', 'can', 'search', 'online', 'using', 'keywords', 'like', '"women\'s', 'health', 'support', 'groups', '[your', 'city/region]"', 'or', '"[specific', 'hormonal', 'condition]', 'support', 'group', '[your', 'city/region]".', 'Local', 'hospitals', 'or', 'community', 'centers', 'are', 'also', 'potential', 'resources.', '**Specialized', 'Clinics', 'and', 'Hospitals:**', 'Large', 'hospitals', 'or', 'specialized', 'clinics', 'dealing', 'with', "women's", 'health', 'often', 'have', 'support', 'systems', 'in', 'place.', 'They', 'might', 'offer', 'individual', 'counseling', 'or', 'group', 'sessions,', 'sometimes', 'led', 'by', 'therapists', 'or', 'medical', 'professionals', 'specializing', 'in', 'hormonal', 'health', 'issues.', 'Inquiring', 'directly', 'with', 'these', 'facilities', 'is', 'a', 'good', 'approach.', '**Professional', 'Organizations:**', 'Many', 'professional', 'organizations', 'dedicated', 'to', "women's", 'health', 'offer', 'resources', 'and', 'may', 'connect', 'you', 'with', 'support', 'networks.', 'Check', 'the', 'websites', 'of', 'organizations', 'such', 'as', 'the', 'American', 'College', 'of', 'Obstetricians', 'and', 'Gynecologists', '(ACOG)', 'or', 'other', 'relevant', 'national', 'or', 'international', 'organizations.', 'Their', 'websites', 'may', 'have', 'a', 'section', 'listing', 'support', 'or', 'referral', 'resources.', '**Important', 'Considerations', 'when', 'choosing', 'a', 'support', 'group:**', '*', '**Moderation:**', 'Look', 'for', 'groups', 'that', 'are', 'actively', 'moderated', 'to', 'ensure', 'a', 'safe', 'and', 'respectful', 'environment.', '*', '**Focus:**', 'Choose', 'a', 'group', 'that', 'specifically', 'addresses', 'your', 'concerns.', 'A', 'general', "women's", 'health', 'group', 'might', 'be', 'less', 'helpful', 'than', 'one', 'focused', 'on', 'a', 'particular', 'hormonal', 'condition.', '*', '**Privacy:**', 'Consider', 'your', 'comfort', 'level', 'with', 'sharing', 'personal', 'details.', 'Online', 'anonymity', 'can', 'be', 'advantageous,', 'but', 'in-person', 'groups', 'require', 'a', 'higher', 'degree', 'of', 'trust.', '*', '**Professional', 'Guidance:**', 'Some', 'groups', 'are', 'led', 'by', 'healthcare', 'professionals,', 'which', 'can', 'offer', 'additional', 'support', 'and', 'medical', 'oversight.', 'Remember', 'that', 'building', 'a', 'supportive', 'network', 'takes', 'time.', "Don't", 'hesitate', 'to', 'explore', 'multiple', 'options', 'until', 'you', 'find', 'a', 'community', 'that', 'feels', 'right', 'for', 'you.', 'Your', 'well-being', 'is', 'paramount,', 'and', 'finding', 'the', 'appropriate', 'support', 'can', 'make', 'a', ' ...
# [17:19:39] Processing query: I'm experiencing shame and embarrassment about my periods. How can I deal with these feelings?...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [17:19:50] NLG metrics error: Predictions and/or references don't match the expected format.
# Expected format:
# Feature option 0: {'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id='references')}
# Feature option 1: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')},
# Input predictions: ['No."', '-*', '*', ..., '0.', 'Do', 'you'],
# Input references: [["It's", 'completely', 'understandable', 'to', 'feel', 'shame', 'or', 'embarrassment', 'around', 'menstruation.', 'For', 'centuries,', 'societal', 'norms', 'have', 'often', 'shrouded', 'periods', 'in', 'secrecy', 'and', 'negativity,', 'leading', 'many', 'women', 'to', 'internalize', 'these', 'feelings.', 'But', 'the', 'truth', 'is,', 'menstruation', 'is', 'a', 'natural,', 'healthy', 'bodily', 'function,', 'a', 'sign', 'of', 'reproductive', 'health,', 'and', 'nothing', 'to', 'be', 'ashamed', 'of.', "Let's", 'work', 'on', 'dismantling', 'those', 'feelings:', '**1.', 'Reframe', 'your', 'thinking:**', 'Periods', 'are', 'not', 'something', 'to', 'be', 'ashamed', 'of;', "they're", 'a', 'biological', 'process', 'essential', 'for', 'potential', 'childbearing.', 'Think', 'of', 'it', 'like', 'any', 'other', 'bodily', 'function', '–', 'digestion,', 'sweating,', 'breathing.', 'These', 'are', 'all', 'natural', 'and', 'necessary,', 'and', 'so', 'is', 'menstruation.', 'Challenge', 'every', 'negative', 'thought', 'with', 'a', 'positive', 'counterpoint.', 'For', 'instance,', 'instead', 'of', '"My', 'period', 'is', 'embarrassing,"', 'try', '"My', 'period', 'is', 'a', 'sign', 'that', 'my', 'body', 'is', 'working', 'perfectly."', '**2.', 'Educate', 'yourself:**', 'The', 'more', 'you', 'understand', 'your', 'menstrual', 'cycle,', 'the', 'less', 'mysterious', 'and', 'potentially', 'embarrassing', 'it', 'will', 'feel.', 'Learn', 'about', 'the', 'hormonal', 'changes,', 'the', 'different', 'phases,', 'and', "what's", 'considered', 'normal', 'variation', 'in', 'flow,', 'duration,', 'and', 'cramping.', 'The', 'better', 'informed', 'you', 'are,', 'the', 'more', 'confident', 'and', 'empowered', "you'll", 'feel.', '**3.', 'Talk', 'to', 'someone', 'you', 'trust:**', 'Sharing', 'your', 'feelings', 'with', 'a', 'trusted', 'friend,', 'family', 'member,', 'or', 'therapist', 'can', 'be', 'incredibly', 'liberating.', 'Talking', 'it', 'out', 'can', 'help', 'you', 'process', 'your', 'emotions', 'and', 'gain', 'a', 'new', 'perspective.', 'Even', 'if', 'they', "haven't", 'experienced', 'the', 'same', 'feelings,', 'simply', 'having', 'someone', 'listen', 'can', 'make', 'a', 'difference.', '**4.', 'Challenge', 'societal', 'norms:**', 'The', 'shame', 'and', 'embarrassment', 'associated', 'with', 'periods', 'are', 'largely', 'socially', 'constructed,', 'not', 'biologically', 'inherent.', 'Actively', 'challenge', 'these', 'norms', 'by', 'openly', 'discussing', 'menstruation', 'with', 'others', 'who', 'are', 'comfortable', 'and', 'educating', 'those', 'who', 'are', 'misinformed.', 'This', 'can', 'be', 'as', 'simple', 'as', 'talking', 'to', 'a', 'friend', 'or', 'family', 'member,', 'or', 'participating', 'in', 'online', 'conversations', 'about', 'menstrual', 'health.', '**5.', 'Practice', 'self-compassion:**', 'Be', 'kind', 'to', 'yourself.', "It's", 'okay', 'to', 'feel', 'these', 'emotions.', 'Recognize', 'that', "it's", 'a', 'learned', 'response,', 'and', 'actively', 'work', 'on', 'changing', 'your', 'perspective.', 'Treat', 'yourself', 'with', 'the', 'same', 'understanding', 'and', 'empathy', 'you', 'would', 'offer', 'a', 'friend', 'struggling', 'with', 'similar', 'feelings.', '**6.', 'Consider', 'professional', 'support:**', 'If', 'the', 'feelings', 'of', 'shame', 'and', 'embarrassment', 'are', 'significantly', 'impacting', 'your', 'daily', 'life,', 'consider', 'seeking', 'professional', 'help', 'from', 'a', 'therapist', 'or', 'counselor.', 'They', 'can', 'provide', 'guidance', 'and', 'tools', 'to', 'help', 'you', 'manage', 'these', 'emotions', 'more', 'effectively.', 'Cognitive', 'Behavioral', 'Therapy', '(CBT)', 'is', 'often', 'particularly', 'helpful', 'in', 'addressing', 'these', 'kinds', 'of', 'learned', 'responses.', 'Remember,', "you're", 'not', 'alone', 'in', 'feeling', 'this', 'way.', 'Millions', 'of', 'women', 'share', 'similar', 'experiences.', 'By', 'actively', 'challenging', 'your', 'negative', 'thoughts,', 'educating', 'yourself,', 'and' ...
# [17:19:50] Processed 10/10
#
# ================================================================================
# EVALUATION RESULTS:
# Average Retrieval Score: 0.840
# Average Completeness Score: 0.042
# Average Faithfulness Score: 0.590
# Average Composite Score: 0.526
# [17:19:50] Saved eval_results.pkl
